# %% [markdown]
# # Analyse original CSV (nb_enfants & quotient_caf missing)

# %% [markdown]
# ### Requirements

# %%
import os

# Get base dir
BASE_DIR = os.path.abspath("..")

# Set data folder name
data_folder = "data"

# %%
# Libraries
import pandas as pd
import seaborn as sns
import missingno as msno

# %%
# Import csv file
data_file_path = os.path.join(BASE_DIR, data_folder, "data.csv")
df = pd.read_csv(data_file_path)

# %% [markdown]
# ### Display CSV columns

# %%
df.head()
# Out:
#       nom    prenom  age  taille  poids sexe sport_licence niveau_etude  \
# 0  Foster    Steven   19   175.0   62.5    H           non          bac
# 1   Tapia      Todd   31   190.0   63.5    H           oui        bac+2
# 2   Hardy  Michelle   68   174.6   66.5    H           oui     doctorat
# 3  Newton   Kenneth   50   187.1  106.8    H           oui       master
# 4  Davila  Kathleen   42   169.7   63.4    H           oui       master
#
#                        region smoker nationalité_francaise  \
# 0               Île-de-France    oui                   oui
# 1                       Corse    non                   oui
# 2        Auvergne-Rhône-Alpes    oui                   oui
# 3                   Occitanie    non                   non
# 4  Provence-Alpes-Côte d’Azur    non                   non
#
#    revenu_estime_mois situation_familiale  historique_credits  \
# 0                4958                veuf                 NaN
# ...

# %% [markdown]
# ### Display empty columns

# %%
# %matplotlib inline
msno.matrix(df.sample(250))
# Out:
# <Axes: >

# %% [markdown]
# ### Display outliers

# %%
sns.boxplot(x=df["revenu_estime_mois"])
# Out:
# <Axes: xlabel='revenu_estime_mois'>

# %%
sns.boxplot(x=df["loyer_mensuel"])
# Out:
# <Axes: xlabel='loyer_mensuel'>
