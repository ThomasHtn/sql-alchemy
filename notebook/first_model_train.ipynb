# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

#from module import simple_model_train
from module.generate_model import simple_model_train

numerical_cols = [
    "age",
    "taille",
    "poids",
    "niveau_etude",
    "revenu_estime_mois",
    "situation_familiale",
    "historique_credits",
    "risque_personnel",
    "score_credit",
    "loyer_mensuel",
]
categorical_cols = [
    "sport_licence",
    "region",
    "smoker",
]

predict_col = "montant_pret"

simple_model_train("clean-data.csv", numerical_cols, categorical_cols, predict_col)
# Out:
# 2025-06-23 16:23:16.901707: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-23 16:23:16.904394: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-06-23 16:23:16.911651: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750688596.923676  172630 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750688596.927120  172630 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1750688596.937160  172630 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750688596.937179  172630 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750688596.937181  172630 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1750688596.937182  172630 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-06-23 16:23:16.940559: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/thomas/atlas/projects/sql-alchemy/.venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# E0000 00:00:1750688598.694122  172630 cuda_executor.cc:1228] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1750688598.694608  172630 gpu_device.cc:2341] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# =================Performance=after=training=================
# MSE: 82569340.7656, MAE: 7012.7918, R²: 0.2771
# ============================================================
# Model and preprocessor saved.
# 2025/06/23 16:23:32 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/06/23 16:23:36 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
