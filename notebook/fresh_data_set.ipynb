# %% [markdown]
# ### Analyse original CSV

# %%
import sys
import os

# Add the parent directory to sys.path
sys.path.append(os.path.abspath(os.path.join("..")))

# %%
# Libraries

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import missingno as msno

from utils import outliers

# %%
# Import csv file
df = pd.read_csv('../data/fresh-data.csv')
df.head()
# Out:
#       nom    prenom  age  taille  poids sexe sport_licence niveau_etude  \
# 0  Foster    Steven   19   175.0   62.5    H           non          bac
# 1   Tapia      Todd   31   190.0   63.5    H           oui        bac+2
# 2   Hardy  Michelle   68   174.6   66.5    H           oui     doctorat
# 3  Newton   Kenneth   50   187.1  106.8    H           oui       master
# 4  Davila  Kathleen   42   169.7   63.4    H           oui       master
#
#                        region smoker  ... nb_enfants quotient_caf  \
# 0               Île-de-France    oui  ...          0         78.7
# 1                       Corse    non  ...          1        221.8
# 2        Auvergne-Rhône-Alpes    oui  ...          2        227.8
# 3                   Occitanie    non  ...          2         64.0
# 4  Provence-Alpes-Côte d’Azur    non  ...          2         19.5
#
#    revenu_estime_mois  situation_familiale  historique_credits  \
# 0                4958                 veuf                 NaN
# 1                3001                 veuf                 NaN
# 2                3758                  NaN                 NaN
# 3                3967                marié                 NaN
# 4                2091                  NaN                 3.0
#
#   risque_personnel  date_creation_compte  score_credit loyer_mensuel  \
# 0             0.19            2021-04-04           NaN           NaN
# 1             0.93            2023-03-19           NaN       1270.84
# 2             0.68            2024-08-27         576.0           NaN
# 3             0.68            2022-03-18           NaN      10000.00
# 4             0.92            2020-10-17           NaN       5000.00
#
#    montant_pret
# 0    500.000000
# 1    786.595929
# 2  29093.676397
# 3   7823.303925
# 4    500.000000
#
# [5 rows x 22 columns]

# %%
df.count
# Out:
# <bound method DataFrame.count of              nom    prenom  age  taille  poids sexe sport_licence  \
# 0         Foster    Steven   19   175.0   62.5    H           non
# 1          Tapia      Todd   31   190.0   63.5    H           oui
# 2          Hardy  Michelle   68   174.6   66.5    H           oui
# 3         Newton   Kenneth   50   187.1  106.8    H           oui
# 4         Davila  Kathleen   42   169.7   63.4    H           oui
# ...          ...       ...  ...     ...    ...  ...           ...
# 9995  Richardson   Gregory   49   147.0   54.8    F           oui
# 9996      Parker  Isabella   72   166.4   54.3    H           non
# 9997       Lewis      Lori   36   165.9   78.8    H           oui
# 9998       Brown     Julia   43   165.0   82.8    H           oui
# 9999       Weber  Michelle   50   159.6   69.5    F           oui
#
#      niveau_etude                      region smoker  ... nb_enfants  \
# 0             bac               Île-de-France    oui  ...          0
# 1           bac+2                       Corse    non  ...          1
# 2        doctorat        Auvergne-Rhône-Alpes    oui  ...          2
# 3          master                   Occitanie    non  ...          2
# 4          master  Provence-Alpes-Côte d’Azur    non  ...          2
# ...           ...                         ...    ...  ...        ...
# 9995     doctorat                       Corse    non  ...          4
# 9996     doctorat                       Corse    oui  ...          0
# 9997     doctorat             Hauts-de-France    oui  ...          1
# 9998       master  Provence-Alpes-Côte d’Azur    oui  ...          0
# 9999       master        Auvergne-Rhône-Alpes    non  ...          3
#
#      quotient_caf  revenu_estime_mois  situation_familiale  \
# 0            78.7                4958                 veuf
# 1           221.8                3001                 veuf
# 2           227.8                3758                  NaN
# 3            64.0                3967                marié
# 4            19.5                2091                  NaN
# ...           ...                 ...                  ...
# 9995        221.2                1923                 veuf
# 9996        337.8                4019              divorcé
# 9997        476.7                2381                  NaN
# 9998        154.2                2128                 veuf
# 9999        277.2                3078                  NaN
#
#       historique_credits risque_personnel  date_creation_compte  score_credit  \
# 0                    NaN             0.19            2021-04-04           NaN
# 1                    NaN             0.93            2023-03-19           NaN
# 2                    NaN             0.68            2024-08-27         576.0
# 3                    NaN             0.68            2022-03-18           NaN
# 4                    3.0             0.92            2020-10-17           NaN
# ...                  ...              ...                   ...           ...
# 9995                 2.0             0.25            2025-01-29           NaN
# 9996                 1.0             0.83            2020-08-02         590.0
# 9997                 NaN             0.41            2025-02-27           NaN
# 9998                 1.0             0.91            2021-02-21           NaN
# 9999                 NaN             0.68            2024-09-30           NaN
#
#      loyer_mensuel  montant_pret
# 0              NaN    500.000000
# 1          1270.84    786.595929
# 2              NaN  29093.676397
# 3         10000.00   7823.303925
# 4          5000.00    500.000000
# ...            ...           ...
# 9995           NaN  15188.992156
# 9996           NaN   1544.589148
# 9997       5000.00  13285.788693
# 9998       5000.00    500.000000
# 9999      10000.00  28449.085511
#
# [10000 rows x 22 columns]>

# %%
# %matplotlib inline
msno.matrix(df.sample(250))
# Out:
# <Axes: >

# %%
sns.boxplot(x=df["loyer_mensuel"])
# Out:
# <Axes: xlabel='loyer_mensuel'>
